# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/Python_krouzek_pro_dospele/blob/main/Python_lekce_II_VII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.mkdir("slozka_pro_ulozeni_jsonu")

# %%
employee = {'Job': 'Programmer', 'Age': 38, 'Full Name': 'Galagher, Fred', 'City': 'London', 'Surname': 'Galagher', 'Gender': 'Male', 'Name': 'Fred'}

# %%
import json
dir(json)
# Out:
# ['JSONDecodeError',
#  'JSONDecoder',
#  'JSONEncoder',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_default_decoder',
#  '_default_encoder',
#  'codecs',
#  'decoder',
#  'detect_encoding',
#  'dump',
#  'dumps',
#  'encoder',
#  'load',
#  'loads',
#  'scanner']

# %%
# !pip install yelpapi

# %%
to_json = json.dumps(employee) #Prevadim na string
print(type(to_json) , to_json)
# Out:
# <class 'str'> {"Job": "Programmer", "Age": 38, "Full Name": "Galagher, Fred", "City": "London", "Surname": "Galagher", "Gender": "Male", "Name": "Fred"}

# %% [markdown]
# Prevod dat z pythonu do jsonu

# %%
#pomoci stringu
with open("slozka_pro_ulozeni_jsonu/test.json", mode="w") as f:
  f.write(to_json)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-5820d6a6a387> in <module>()
#       1 with open("slozka_pro_ulozeni_jsonu/test.json", mode="w") as f:
# ----> 2   f.write(employee)
#
# TypeError: write() argument must be str, not dict

# %%
with open("slozka_pro_ulozeni_jsonu/testII.json", mode="w") as f:
  json.dump(employee, f, indent=4)

# %% [markdown]
# Pevod dat z jsonu do pythonu

# %%
#pomoci stringu
with open("slozka_pro_ulozeni_jsonu/testII.json", mode="r") as f:
  data = f.read()
  data = json.loads(data)
data
# Out:
# {'Age': 38,
#  'City': 'London',
#  'Full Name': 'Galagher, Fred',
#  'Gender': 'Male',
#  'Job': 'Programmer',
#  'Name': 'Fred',
#  'Surname': 'Galagher'}

# %%
with open("slozka_pro_ulozeni_jsonu/testII.json", mode="r") as f:
  data = json.load(f)
data
# Out:
# {'Age': 38,
#  'City': 'London',
#  'Full Name': 'Galagher, Fred',
#  'Gender': 'Male',
#  'Job': 'Programmer',
#  'Name': 'Fred',
#  'Surname': 'Galagher'}

# %%
# %%writefile pocasi.json
# [
#     {
#         "address_components":
#             {
#                 "long_name": "Praha - venkov",
#                 "types": [
#                     "locality",
#                     "political"
#                 ],
#                 "short_name": "Brno"
#             },
#         "formatted_address": "Brno, Czechia",
#         "place_id": "ChIJEVE_wDqUEkcRsLEUZg-vAAQ",
#         "weather": {
#             "wind": {
#                 "direction": "north",
#                 "speed": "20"
#             },
#             "rain": {
#                 "raining": true,
#                 "intensity": "light",
#                 "intensity-value":"2"
#             },
#             "clouds": {
#                 "type": "cumulus"
#             },
#             "temperature": {
#                 "min": "15",
#                 "max": "18",
#                 "current": "16.5"
#             }
#         }
#     }
# ]
# Out:
# Writing pocasi.json

# %%
with open("pocasi.json","r") as f:
  data = f.read()

# %%
data = json.loads(data)

# %%
data
# Out:
# [{'address_components': {'long_name': 'Praha - venkov',
#    'short_name': 'Brno',
#    'types': ['locality', 'political']},
#   'formatted_address': 'Brno, Czechia',
#   'place_id': 'ChIJEVE_wDqUEkcRsLEUZg-vAAQ',
#   'weather': {'clouds': {'type': 'cumulus'},
#    'rain': {'intensity': 'light', 'intensity-value': '2', 'raining': True},
#    'temperature': {'current': '16.5', 'max': '18', 'min': '15'},
#    'wind': {'direction': 'north', 'speed': '20'}}}]

# %%
slovnik = data[0]

# %%
slovnik.keys()
# Out:
# dict_keys(['address_components', 'formatted_address', 'place_id', 'weather'])

# %%
min_teplota = slovnik["weather"]["temperature"]["min"]

# %% [markdown]
# Yelp data

# %%
slovnik = {'businesses': [{'alias': 'lokál-dlouhááá-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0907066889726,
    'longitude': 14.4257936335599},
   'display_phone': '+420 734 283 874',
   'distance': 1426.5780844053368,
   'id': 'qCU20ZREPVB9N6L365L5Ow',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I7XdPRQxI8_XTlEvYfOu3w/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Dlouhá 33',
    'address2': '',
    'address3': None,
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Dlouhá 33', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Lokál Dlouhááá',
   'phone': '+420734283874',
   'price': '$$',
   'rating': 4.0,
   'review_count': 481,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/lok%C3%A1l-dlouh%C3%A1%C3%A1%C3%A1-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'kro-kitchen-bistro-a-rotisserie-prahy',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'bistros', 'title': 'Bistros'}],
   'coordinates': {'latitude': 50.07708, 'longitude': 14.45075},
   'display_phone': '+420 721 030 017',
   'distance': 1960.2584874360048,
   'id': '95W4u_NojRIKH3H3tH6Piw',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dH3n7Bf653HPeAtUerxsbw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Vinohradská 66',
    'address2': '',
    'address3': None,
    'city': 'Prahy',
    'country': 'CZ',
    'display_address': ['Vinohradská 66', '130 00 Prahy', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '130 00'},
   'name': 'Kro Kitchen bistro & rotisserie',
   'phone': '+420721030017',
   'rating': 5.0,
   'review_count': 2,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/kro-kitchen-bistro-a-rotisserie-prahy?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'czechouse-grill-a-rotisserie-praha-2',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'steak', 'title': 'Steakhouses'}],
   'coordinates': {'latitude': 50.09334, 'longitude': 14.4396573},
   'display_phone': '+420 224 842 700',
   'distance': 395.14319556798216,
   'id': '9ZRuImwrzo5NdLli_I65HA',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4ySzOcg2IsDs1qtjRS82Sw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Pobřežní 1',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Pobřežní 1', '186 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '186 00'},
   'name': 'Czechouse Grill & Rotisserie',
   'phone': '+420224842700',
   'price': '$$$$',
   'rating': 4.5,
   'review_count': 10,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/czechouse-grill-a-rotisserie-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'restaurace-mincovna-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0884514, 'longitude': 14.4212799},
   'display_phone': '+420 727 955 669',
   'distance': 1819.5918298816966,
   'id': 'e-p6rFWXVCyQWasTP98nsw',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w97dNMOwus8hsNLAXaGQrQ/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Staroměstské nám. 930/7',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Staroměstské nám. 930/7',
     '110 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Restaurace Mincovna',
   'phone': '+420727955669',
   'price': '$$',
   'rating': 4.5,
   'review_count': 197,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/restaurace-mincovna-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'u-parlamentu-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0881905, 'longitude': 14.4166166},
   'display_phone': '+420 721 415 747',
   'distance': 2135.443388981751,
   'id': '3l-vxXn4NcRgErbZ0lxfCA',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V5MPGfes1rAXvTXfnjj0aw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Valentinská 52/8',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Valentinská 52/8', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'U Parlamentu',
   'phone': '+420721415747',
   'price': '$$',
   'rating': 4.5,
   'review_count': 144,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/u-parlamentu-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'srdcovka-spálená-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0807153, 'longitude': 14.4195523},
   'display_phone': '+420 773 821 218',
   'distance': 2364.236953018407,
   'id': 'IvV_V92J_1FybGnvnMiTug',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aBbv9RdGO5yVYTLFejlarw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Spálená 99/33',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Spálená 99/33', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Srdcovka Spálená',
   'phone': '+420773821218',
   'rating': 3.5,
   'review_count': 3,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/srdcovka-sp%C3%A1len%C3%A1-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'mlejnice-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'bbq', 'title': 'Barbeque'}],
   'coordinates': {'latitude': 50.08646, 'longitude': 14.42155},
   'display_phone': '+420 224 228 635',
   'distance': 1887.318283157394,
   'id': 'Kb846sGQ1_o9pZXKiCqJqA',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d7VYOUwUCA8ksISHydrowQ/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Kožná 488/14',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Kožná 488/14', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Mlejnice',
   'phone': '+420224228635',
   'price': '$$',
   'rating': 4.0,
   'review_count': 384,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/mlejnice-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'pivovar-marina-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'breweries', 'title': 'Breweries'}],
   'coordinates': {'latitude': 50.1077981246394,
    'longitude': 14.4553738832474},
   'display_phone': '+420 220 571 183',
   'distance': 1668.2168051054048,
   'id': 'zc_zSSuVNxMu5fuXOfx1uQ',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EKebnhBx5vnVc5ypHzUXGw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Jankovcova12',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Jankovcova12', '170 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '170 00'},
   'name': 'Pivovar Marina',
   'phone': '+420220571183',
   'price': '$$$',
   'rating': 4.0,
   'review_count': 6,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/pivovar-marina-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'pivovar-u-tří-růží-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'brewpubs', 'title': 'Brewpubs'}],
   'coordinates': {'latitude': 50.0856387, 'longitude': 14.4183579},
   'display_phone': '+420 601 588 281',
   'distance': 2131.535675695737,
   'id': 'xF-FfD3ifmy90kjaPip7NA',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q-tyef06-gRSnic3oosbyA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Husova 10',
    'address2': '',
    'address3': None,
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Husova 10', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Pivovar U Tří růží',
   'phone': '+420601588281',
   'price': '$$',
   'rating': 4.5,
   'review_count': 243,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/pivovar-u-t%C5%99%C3%AD-r%C5%AF%C5%BE%C3%AD-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'u-houdků-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0824652, 'longitude': 14.4457724},
   'display_phone': '+420 222 711 239',
   'distance': 1324.3613779767468,
   'id': 'xFxxFBEaNnUywNqW1w4U4A',
   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vDQrlQlAGsyQcb41YmzlaA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Bořivojova 110',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Bořivojova 110', '130 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '130 00'},
   'name': 'U Houdků',
   'phone': '+420222711239',
   'price': '$',
   'rating': 4.5,
   'review_count': 28,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/u-houdk%C5%AF-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'hostinec-u-přístavu-praha-7',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.1050699900214,
    'longitude': 14.4555079936981},
   'display_phone': '+420 724 151 566',
   'distance': 1408.1922719821089,
   'id': 'NTFFCjHIE8xuNSRecv_iNw',
   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lMhAfy11ukHEwKrnw4iZ4g/o.jpg',
   'is_closed': False,
   'location': {'address1': 'U Průhonu 64',
    'address2': '',
    'address3': None,
    'city': 'Praha-7',
    'country': 'CZ',
    'display_address': ['U Průhonu 64', '170 00 Praha-7', 'Czech Republic'],
    'state': 'JC',
    'zip_code': '170 00'},
   'name': 'Hostinec U přístavu',
   'phone': '+420724151566',
   'price': '$',
   'rating': 3.0,
   'review_count': 1,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/hostinec-u-p%C5%99%C3%ADstavu-praha-7?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'lokál-u-bílé-kuželky-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0876784495257,
    'longitude': 14.4075028377176},
   'display_phone': '+420 257 212 014',
   'distance': 2773.755026453583,
   'id': 'p9zNnE3q93w0HkYYRBHAng',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FMkCRWfTU6p1cT9IorMJkg/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Míšeňská 66/12',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Míšeňská 66/12', '118 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '118 00'},
   'name': 'Lokál U Bílé kuželky',
   'phone': '+420257212014',
   'price': '$$',
   'rating': 4.0,
   'review_count': 124,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/lok%C3%A1l-u-b%C3%ADl%C3%A9-ku%C5%BEelky-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'café-imperial-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
   'coordinates': {'latitude': 50.0898464, 'longitude': 14.4328659},
   'display_phone': '+420 246 011 440',
   'distance': 998.4510724044495,
   'id': 'mJ3btedhWhB4SGZs0rvXKA',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PTEQGIzmt8a6xZWXG-0LKg/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Na Poříčí 15',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Na Poříčí 15', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Café Imperial',
   'phone': '+420246011440',
   'price': '$$',
   'rating': 4.5,
   'review_count': 174,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/caf%C3%A9-imperial-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'u-modré-kachničky-ii-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0855769, 'longitude': 14.4201431},
   'display_phone': '+420 224 213 418',
   'distance': 2022.2809277674708,
   'id': 'aApBpUqYgIaNPDF86L1Ntw',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cdSqUF-A3y910ceKUiUs1Q/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Michalská 434/16',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Michalská 434/16', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'The Blue Duckling 2',
   'phone': '+420224213418',
   'price': '$$$',
   'rating': 4.5,
   'review_count': 71,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/u-modr%C3%A9-kachni%C4%8Dky-ii-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'klášterní-pivovar-strahov-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'breweries', 'title': 'Breweries'}],
   'coordinates': {'latitude': 50.0868126467701,
    'longitude': 14.3885713459754},
   'display_phone': '+420 233 353 155',
   'distance': 4109.568312859692,
   'id': 'rwdp34YhCYCHmLZzrUYVSw',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GIiKrf29BJUqzX5oJApVaA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Strahovské nádvoří 301',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Strahovské nádvoří 301',
     '118 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '118 00'},
   'name': 'Klášterní pivovar Strahov',
   'phone': '+420233353155',
   'price': '$$',
   'rating': 4.0,
   'review_count': 117,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/kl%C3%A1%C5%A1tern%C3%AD-pivovar-strahov-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'planeta-žižkov-praha-3',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0875333, 'longitude': 14.4528532},
   'display_phone': '+420 222 780 173',
   'distance': 945.4470199659814,
   'id': 'mbD1E_r1Vv-SjX9T13RWzg',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0DIcwWVdO3_4LQQ2k21-pA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Tachovské náměstí 79/1',
    'address2': '',
    'address3': '',
    'city': 'Praha-3',
    'country': 'CZ',
    'display_address': ['Tachovské náměstí 79/1',
     '130 00 Praha-3',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '130 00'},
   'name': 'Planeta Žižkov',
   'phone': '+420222780173',
   'price': '$',
   'rating': 3.0,
   'review_count': 10,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/planeta-%C5%BEi%C5%BEkov-praha-3?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'lavička-praha-3',
   'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
    {'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0844385, 'longitude': 14.4514256},
   'display_phone': '+420 222 221 350',
   'distance': 1196.1467634012517,
   'id': '2jq7GViVkdj_mvP-eXwqdA',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eAHKVAlolv2A6b2GX0dxnw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Seifertova 77',
    'address2': '',
    'address3': '',
    'city': 'Praha-3',
    'country': 'CZ',
    'display_address': ['Seifertova 77', '130 00 Praha-3', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '130 00'},
   'name': 'Lavička',
   'phone': '+420222221350',
   'price': '$$',
   'rating': 4.5,
   'review_count': 51,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/lavi%C4%8Dka-praha-3?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'pivovarský-dům-praha',
   'categories': [{'alias': 'breweries', 'title': 'Breweries'},
    {'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0753593, 'longitude': 14.42383},
   'display_phone': '+420 224 921 256',
   'distance': 2599.224525536566,
   'id': 'qcMtcJJ0AOAFBEii8lb1aA',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2JDowK7NMmxykDx2G9Jpuw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Lípová 511/15',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Lípová 511/15', '120 44 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '120 44'},
   'name': 'Pivovarský dům',
   'phone': '+420224921256',
   'price': '$$',
   'rating': 3.5,
   'review_count': 60,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/pivovarsk%C3%BD-d%C5%AFm-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'baráčnická-rychta-praha-2',
   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
    {'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0879606, 'longitude': 14.4001754},
   'display_phone': '+420 257 532 461',
   'distance': 3273.3808278322326,
   'id': 'CfltZrrH910Zi1VzTOjWKA',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ktg5lvwTU2NU9fSzyoZLzQ/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Tržiště 23/555',
    'address2': None,
    'address3': None,
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Tržiště 23/555', '118 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '118 00'},
   'name': 'Baráčnická rychta',
   'phone': '+420257532461',
   'price': '$$',
   'rating': 4.5,
   'review_count': 62,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/bar%C3%A1%C4%8Dnick%C3%A1-rychta-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'karlův-sklep-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0774333, 'longitude': 14.4192564},
   'display_phone': '+420 224 923 960',
   'distance': 2628.2580629455438,
   'id': 'BGLEaHFbmGGNNCGPjVSi0w',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QDLAjEI2n438BvRMPBMo5A/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Karlovo náměstí 18',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Karlovo náměstí 18',
     '120 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '120 00'},
   'name': 'Karlův sklep',
   'phone': '+420224923960',
   'price': '$$',
   'rating': 4.0,
   'review_count': 10,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/karl%C5%AFv-sklep-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'u-sádlů-praha-2',
   'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
    {'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0913802, 'longitude': 14.4280862},
   'display_phone': '+420 224 813 874',
   'distance': 1248.715300418093,
   'id': 'PGjPnhldWqLygodWZxcIbQ',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nsvelsbJkIzCkjy_zADbmQ/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Klimentská 2',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Klimentská 2', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'U Sádlů',
   'phone': '+420224813874',
   'price': '$$',
   'rating': 4.0,
   'review_count': 27,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/u-s%C3%A1dl%C5%AF-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'pivnice-u-zlatého-slona-praha-1',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'brasseries', 'title': 'Brasseries'}],
   'coordinates': {'latitude': 50.0850356, 'longitude': 14.4205141},
   'display_phone': '+420 224 222 046',
   'distance': 2029.254778278987,
   'id': 'THZRLvVojGtMc64ghRpZ8w',
   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qEPB4gYtj0PfBJ0uYcjPSg/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Havelská 9',
    'address2': '',
    'address3': '',
    'city': 'Praha-1',
    'country': 'CZ',
    'display_address': ['Havelská 9', '110 00 Praha-1', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Pivnice U Zlatého slona',
   'phone': '+420224222046',
   'price': '$',
   'rating': 4.5,
   'review_count': 10,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/pivnice-u-zlat%C3%A9ho-slona-praha-1?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'u-kroka-praha-2',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0665822, 'longitude': 14.4178374},
   'display_phone': '+420 775 905 022',
   'distance': 3645.424298990874,
   'id': 'l0J82xnEYm_Yg4iG2PkmHg',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qpQTTEEgrcbo5VFwT7WKPA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Vratislavova 12',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Vratislavova 12', '128 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '128 00'},
   'name': 'U Kroka',
   'phone': '+420775905022',
   'price': '$$',
   'rating': 4.5,
   'review_count': 139,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/u-kroka-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'u-dvou-sester-praha-2',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0857886881629,
    'longitude': 14.4208693343516},
   'display_phone': '+420 773 099 994',
   'distance': 1965.5428518321683,
   'id': 'pR05nYloCmeQNpYFdHeBVQ',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PPM3IDdKqrO99ovyRTMrPw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Melantrichova 471/10',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Melantrichova 471/10',
     '110 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'U Dvou Sester',
   'phone': '+420773099994',
   'price': '$$',
   'rating': 4.0,
   'review_count': 18,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/u-dvou-sester-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'plzeňská-restaurace-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0875565563428,
    'longitude': 14.4280937050809},
   'display_phone': '+420 222 002 135',
   'distance': 1421.6273423460054,
   'id': 'ecO0xCzfywQRQOKXSlPXKA',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V6HpHitXBYyx9WFoCyLF5w/o.jpg',
   'is_closed': False,
   'location': {'address1': 'náměstí Republiky 1090/5',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['náměstí Republiky 1090/5',
     '110 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Plzeňská restaurace',
   'phone': '+420222002135',
   'price': '$$',
   'rating': 4.0,
   'review_count': 29,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/plze%C5%88sk%C3%A1-restaurace-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'krystal-bistro-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'french', 'title': 'French'}],
   'coordinates': {'latitude': 50.0946035, 'longitude': 14.4531721},
   'display_phone': '+420 606 064 488',
   'distance': 586.2967351952725,
   'id': '6a7qCXYritBKpsyRyl-dcQ',
   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4Iizc8XtcvWOBbNmx6m5GA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Sokolovská 101/99',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Sokolovská 101/99',
     '186 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '186 00'},
   'name': 'Krystal bistro',
   'phone': '+420606064488',
   'price': '$$',
   'rating': 4.0,
   'review_count': 33,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/krystal-bistro-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'švejk-restaurant-u-brázdů-praha-3',
   'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
    {'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.1066051, 'longitude': 14.4883724},
   'display_phone': '+420 266 316 177',
   'distance': 3382.257841980564,
   'id': 'Ud8EjEkuxbjPWc_Ucg3sCQ',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SJxu6vSeTV6pcizcjGNu9A/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Sokolovská 258',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Sokolovská 258', '190 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '190 00'},
   'name': 'Švejk restaurant U Brázdů',
   'phone': '+420266316177',
   'price': '$$',
   'rating': 4.0,
   'review_count': 11,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/%C5%A1vejk-restaurant-u-br%C3%A1zd%C5%AF-praha-3?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'zapomenutý-čas-prague-2',
   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
    {'alias': 'czech', 'title': 'Czech'},
    {'alias': 'beerbar', 'title': 'Beer Bar'}],
   'coordinates': {'latitude': 50.0763662, 'longitude': 14.4342473},
   'display_phone': '+420 222 516 223',
   'distance': 2142.303073469164,
   'id': 'w1QziqbV3oaKj7aNv1vQAQ',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D56TxS8CqYFxOb_DFkoXyA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Anglická 658/23',
    'address2': '',
    'address3': '',
    'city': 'Prague 2',
    'country': 'CZ',
    'display_address': ['Anglická 658/23',
     '120 00 Prague 2',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '120 00'},
   'name': 'Zapomenutý čas',
   'phone': '+420222516223',
   'price': '$$',
   'rating': 4.0,
   'review_count': 10,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/zapomenut%C3%BD-%C4%8Das-prague-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'potrefená-husa-hybernská-praha',
   'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
    {'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0867793, 'longitude': 14.432035},
   'display_phone': '+420 224 243 631',
   'distance': 1249.689268981405,
   'id': 'u9QjSCDyXKDmsIk5-28W7w',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EdDJlZbMLgaBmgxBMn_IJA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Dlážděná 1003/7',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Dlážděná 1003/7', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Potrefená Husa Hybernská',
   'phone': '+420224243631',
   'price': '$$',
   'rating': 4.0,
   'review_count': 79,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/potrefen%C3%A1-husa-hybernsk%C3%A1-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'restaurace-rainer-maria-rilke-praha-1',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0883996654333,
    'longitude': 14.3958969780478},
   'display_phone': '+420 222 221 414',
   'distance': 3562.481084678121,
   'id': 'vr7lBexn5UrJrmfzxZx0Yg',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Aug9pP5QJtWKcj7JlJZyOg/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Úvoz 169/6',
    'address2': '',
    'address3': '',
    'city': 'Praha 1',
    'country': 'CZ',
    'display_address': ['Úvoz 169/6', '110 00 Praha 1', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Restaurace Rainer Maria Rilke',
   'phone': '+420222221414',
   'price': '$$',
   'rating': 4.5,
   'review_count': 10,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/restaurace-rainer-maria-rilke-praha-1?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'apetit-praha-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.09032, 'longitude': 14.42452},
   'display_phone': '+420 222 320 070',
   'distance': 1524.4838078494784,
   'id': '0HbVVB3aXYi1AvlPXvyN3Q',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1Cv55MibWvcnxlf43VWxkQ/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Dlouhá 736/23',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Dlouhá 736/23', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Apetit Praha',
   'phone': '+420222320070',
   'price': '$',
   'rating': 4.0,
   'review_count': 5,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/apetit-praha-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'havlíčkova-restaurace-praha-2',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'international', 'title': 'International'}],
   'coordinates': {'latitude': 50.0887985167476,
    'longitude': 14.4327159241966},
   'display_phone': '+420 777 757 884',
   'distance': 1070.580219159319,
   'id': 'HLzXXhXZR0xhA6s39yrWCQ',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ESzX-EPORuF9LvFryVmxfA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Havlíčkova 4',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Havlíčkova 4', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Havlíčkova restaurace',
   'phone': '+420777757884',
   'price': '$$',
   'rating': 3.5,
   'review_count': 15,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/havl%C3%AD%C4%8Dkova-restaurace-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'bredovský-dvůr-praha-2',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0824976, 'longitude': 14.430021},
   'display_phone': '',
   'distance': 1696.236769135593,
   'id': 'OPwR9XYpBiHEv_XEY3r1Xg',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3Uou60clZwrbQh-saxrqA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Politických vězňů 13',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Politických vězňů 13',
     '110 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Bredovský dvůr',
   'phone': '',
   'price': '$$',
   'rating': 4.5,
   'review_count': 90,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/bredovsk%C3%BD-dv%C5%AFr-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'u-provaznice-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'pubs', 'title': 'Pubs'}],
   'coordinates': {'latitude': 50.084692, 'longitude': 14.423233},
   'display_phone': '+420 224 232 528',
   'distance': 1886.6980040470305,
   'id': '04Z2QWfu921JAFBxO5noaQ',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x9KVTzWYkVvdf7or4IiuJg/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Provaznická 3',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Provaznická 3', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'U Provaznice',
   'phone': '+420224232528',
   'price': '$$',
   'rating': 4.0,
   'review_count': 73,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/u-provaznice-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'restaurace-tiskárna-praha-1-2',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.08426, 'longitude': 14.42902},
   'display_phone': '+420 602 448 854',
   'distance': 1593.6809503082845,
   'id': 'RDY2_KPXALQ-87ocC5ynvA',
   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/98tTq3GWOOv4EwziijQjRA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Jindřišská 940/22',
    'address2': '',
    'address3': None,
    'city': 'Praha 1',
    'country': 'CZ',
    'display_address': ['Jindřišská 940/22',
     '110 00 Praha 1',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Restaurace Tiskárna',
   'phone': '+420602448854',
   'rating': 4.5,
   'review_count': 30,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/restaurace-tisk%C3%A1rna-praha-1-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'restaurace-pod-vyšehradem-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0669720244637,
    'longitude': 14.4170164237606},
   'display_phone': '+420 222 951 522',
   'distance': 3640.514188512661,
   'id': '26v3T88oTG8t1VMRPi9_Sw',
   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kc8rDBJsZKncPXD50ZSaAQ/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Vratislavova 32/4',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Vratislavova 32/4',
     '128 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '128 00'},
   'name': 'Restaurace pod Vyšehradem',
   'phone': '+420222951522',
   'price': '$$',
   'rating': 4.0,
   'review_count': 8,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/restaurace-pod-vy%C5%A1ehradem-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'havelská-koruna-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0855293, 'longitude': 14.4215002},
   'display_phone': '+420 224 239 331',
   'distance': 1939.7099266128835,
   'id': 'DcapazDWzdeFjgEHT9VwJA',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0Uotf12QkP6iRGicDH5aqw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Havelská 21',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Havelská 21', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Havelská Koruna',
   'phone': '+420224239331',
   'price': '$',
   'rating': 4.0,
   'review_count': 74,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/havelsk%C3%A1-koruna-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'kolkovna-celnice-praha-2',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'brasseries', 'title': 'Brasseries'}],
   'coordinates': {'latitude': 50.0878856, 'longitude': 14.4300736},
   'display_phone': '+420 224 212 240',
   'distance': 1283.3485489013462,
   'id': 'FbK1mpYyb4XrvYzSTQEJBg',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-SyjDPIFmRy1s5yHZ7PGrw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'V Celnici 1036/4',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['V Celnici 1036/4', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Kolkovna Celnice',
   'phone': '+420224212240',
   'price': '$$',
   'rating': 3.5,
   'review_count': 78,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/kolkovna-celnice-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'restaurace-u-veverky-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0990368506143,
    'longitude': 14.4022337416773},
   'display_phone': '+420 223 000 223',
   'distance': 3091.77923689486,
   'id': '6vn5FAXm74kNfixCxB8jsg',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8PiwK1y9CF_U2pX-RyLp6g/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Eliášova 324/14',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Eliášova 324/14', '160 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '160 00'},
   'name': 'Restaurace U Veverky',
   'phone': '+420223000223',
   'price': '$',
   'rating': 4.0,
   'review_count': 28,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/restaurace-u-veverky-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'restaurant-zvonice-praha-2',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0851494, 'longitude': 14.4300494},
   'display_phone': '+420 224 220 009',
   'distance': 1477.036994767688,
   'id': 'DDL4CCbQkrUhQRknGN7JGQ',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nrXyfbL9b6jv9o6LhFAr8w/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Jindřišská věž',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Jindřišská věž', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Restaurant Zvonice',
   'phone': '+420224220009',
   'price': '$$$',
   'rating': 5.0,
   'review_count': 29,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/restaurant-zvonice-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'restaurant-u-špirků-praha-2',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0862441018061,
    'longitude': 14.4213817814869},
   'display_phone': '+420 224 210 073',
   'distance': 1909.1854630440916,
   'id': 'FBO2HPfKiMgbDsYd4ZWSeA',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/X8Ad24n9G8R8GB-wFnZlRA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Kožná 12',
    'address2': None,
    'address3': None,
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Kožná 12', '11000 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '11000'},
   'name': 'Restaurant U Špirků',
   'phone': '+420224210073',
   'price': '$$',
   'rating': 3.5,
   'review_count': 15,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/restaurant-u-%C5%A1pirk%C5%AF-praha-2?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'vinohradský-parlament-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'modern_european', 'title': 'Modern European'}],
   'coordinates': {'latitude': 50.075423, 'longitude': 14.4380759},
   'display_phone': '+420 224 250 403',
   'distance': 2162.692251647954,
   'id': 'Vkfmp2M_2RkrW40QUvTRQg',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Qu5YXApJcyO8RLOAsIwpuA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Korunní 1',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Korunní 1', '120 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '120 00'},
   'name': 'Vinohradský Parlament',
   'phone': '+420224250403',
   'price': '$$',
   'rating': 4.0,
   'review_count': 125,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/vinohradsk%C3%BD-parlament-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'čistý-stůl-praha-5-malá-strana',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'french', 'title': 'French'},
    {'alias': 'italian', 'title': 'Italian'}],
   'coordinates': {'latitude': 50.081166, 'longitude': 14.4046211},
   'display_phone': '+420 737 521 426',
   'distance': 3230.622364698438,
   'id': '6MPy7xbHtkHuvrudtvIc-g',
   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WHsF3cMmQhLsMXgk5yyXEw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Vítězná 15',
    'address2': None,
    'address3': '',
    'city': 'Praha 5 - Malá Strana',
    'country': 'CZ',
    'display_address': ['Vítězná 15',
     '150 01 Praha 5 - Malá Strana',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '150 01'},
   'name': 'Čistý stůl',
   'phone': '+420737521426',
   'price': '$$',
   'rating': 4.5,
   'review_count': 17,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/%C4%8Dist%C3%BD-st%C5%AFl-praha-5-mal%C3%A1-strana?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'u-mariánského-obrazu-praha',
   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
    {'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0821411, 'longitude': 14.4495698},
   'display_phone': '+420 222 722 007',
   'distance': 1398.334020346501,
   'id': 'wX08vAnVPSr-tK74jrKdAg',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KSaBU1PGXK81X38HccYzEw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Kubelíkova 22',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Kubelíkova 22', '130 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '130 00'},
   'name': 'U Mariánského Obrazu',
   'phone': '+420222722007',
   'price': '$',
   'rating': 3.5,
   'review_count': 12,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/u-mari%C3%A1nsk%C3%A9ho-obrazu-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'nuance-restaurant-praha',
   'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
    {'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0869001, 'longitude': 14.4192626},
   'display_phone': '+420 224 247 400',
   'distance': 2012.4697989159429,
   'id': '32azTNk0q9BlgqIXyl-0-Q',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oxBg7mvzO22D9BhvA7NCoA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Malé náměstí 138/4',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Malé náměstí 138/4',
     '110 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Nuance Restaurant',
   'phone': '+420224247400',
   'price': '$$$',
   'rating': 4.0,
   'review_count': 10,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/nuance-restaurant-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'ferdinanda-praha-1',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0863, 'longitude': 14.40425},
   'display_phone': '+420 257 534 015',
   'distance': 3039.7333282320114,
   'id': 'mi1LVvHlggjD0C2BMl3ygQ',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4tj_Cr0Pk94YUET-SLMkjg/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Karmelitská 379/18',
    'address2': '',
    'address3': '',
    'city': 'Praha 1',
    'country': 'CZ',
    'display_address': ['Karmelitská 379/18',
     '118 00 Praha 1',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '118 00'},
   'name': 'Ferdinanda',
   'phone': '+420257534015',
   'price': '$$$',
   'rating': 4.0,
   'review_count': 11,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/ferdinanda-praha-1?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'meat-a-greet-praha',
   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
    {'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0859413, 'longitude': 14.4298296},
   'display_phone': '+420 222 222 089',
   'distance': 1428.9820211922772,
   'id': 'yK4Vz-HVL4BtZTauid0etw',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wnB4F8DGukx8pPagDC_JmA/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Senovážné náměstí 994/2',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Senovážné náměstí 994/2',
     '110 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Meat & Greet',
   'phone': '+420222222089',
   'price': '$$',
   'rating': 4.5,
   'review_count': 96,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/meat-a-greet-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'krčma-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'pubs', 'title': 'Pubs'}],
   'coordinates': {'latitude': 50.089, 'longitude': 14.4202},
   'display_phone': '+420 725 157 262',
   'distance': 1864.4291141926005,
   'id': '3vpcCph8QfrYiKE09s-O-g',
   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zSFK2rCqdBjSNpip-9jqgQ/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Kostečná 4',
    'address2': None,
    'address3': None,
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Kostečná 4', '11000 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '11000'},
   'name': 'Krčma',
   'phone': '+420725157262',
   'price': '$$',
   'rating': 4.0,
   'review_count': 54,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/kr%C4%8Dma-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'restaurace-v-cípu-vladislavova-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'},
    {'alias': 'pubs', 'title': 'Pubs'}],
   'coordinates': {'latitude': 50.0793378, 'longitude': 14.42088},
   'display_phone': '+420 607 177 107',
   'distance': 2396.587187469134,
   'id': '5Mz1_TvkzFmD1Ox6NzG4_A',
   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YkHGbKX_f8x6uhrdDsOaSg/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Vladislavova 1719/1',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Vladislavova 1719/1',
     '110 00 Prague',
     'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Restaurace V Cípu - Vladislavova',
   'phone': '+420607177107',
   'price': '$$',
   'rating': 5.0,
   'review_count': 2,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/restaurace-v-c%C3%ADpu-vladislavova-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'},
  {'alias': 'restaurace-staré-časy-praha',
   'categories': [{'alias': 'czech', 'title': 'Czech'}],
   'coordinates': {'latitude': 50.0839294, 'longitude': 14.4209944},
   'display_phone': '+420 222 873 201',
   'distance': 2066.3738844119753,
   'id': '8gEaoqphy7e_7feMHr0wzQ',
   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UqJlipSmXP6MphnqnseWLw/o.jpg',
   'is_closed': False,
   'location': {'address1': 'Rytířská 411/4',
    'address2': '',
    'address3': '',
    'city': 'Prague',
    'country': 'CZ',
    'display_address': ['Rytířská 411/4', '110 00 Prague', 'Czech Republic'],
    'state': 'PR',
    'zip_code': '110 00'},
   'name': 'Restaurace Staré Časy',
   'phone': '+420222873201',
   'price': '$$',
   'rating': 3.5,
   'review_count': 7,
   'transactions': [],
   'url': 'https://www.yelp.com/biz/restaurace-star%C3%A9-%C4%8Dasy-praha?adjust_creative=3qHY6E4NeBeyZsY3pWwtpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3qHY6E4NeBeyZsY3pWwtpg'}],
 'region': {'center': {'latitude': 50.09436411349209,
   'longitude': 14.444961547851562}},
 'total': 117}

# %%
with open("yelp.json", "r") as f:
  data = f.read()

# %%
slovnik.keys()
# Out:
# dict_keys(['businesses', 'region', 'total'])

# %%
slovnik["businesses"][2]
# Out:
# {'alias': 'czechouse-grill-a-rotisserie-praha-2',
#  'categories': [{'alias': 'czech', 'title': 'Czech'},
#   {'alias': 'steak', 'title': 'Steakhouses'}],
#  'coordinates': {'latitude': 50.09334, 'longitude': 14.4396573},
#  'display_phone': '+420 224 842 700',
#  'distance': 395.14319556798216,
#  'id': '9ZRuImwrzo5NdLli_I65HA',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4ySzOcg2IsDs1qtjRS82Sw/o.jpg',
#  'is_closed': False,
#  'location': {'address1': 'Pobřežní 1',
#   'address2': '',
#   'address3': '',
#   'city': 'Prague',
#   'country': 'CZ',
#   'display_address': ['Pobřežní 1', '186 00 Prague', 'Czech Republic'],
#   'state': 'PR',
#   'zip_code': '186 00'},
#  'name': 'Czechouse Grill & Rotisserie',
#  'phone': '+420224842700',
#  'price': '$$$$',
#  'rating': 4.5,
#  'review_count': 10,
#  'transactions': [],
# ...

# %%
for k in slovnik["businesses"]:
  print(k.keys())
# Out:
# dict_keys(['alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id', 'image_url', 'is_closed', 'location', 'name', 'phone', 'price', 'rating', 'review_count', 'transactions', 'url'])
# dict_keys(['alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id', 'image_url', 'is_closed', 'location', 'name', 'phone', 'rating', 'review_count', 'transactions', 'url'])
# dict_keys(['alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id', 'image_url', 'is_closed', 'location', 'name', 'phone', 'price', 'rating', 'review_count', 'transactions', 'url'])
# dict_keys(['alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id', 'image_url', 'is_closed', 'location', 'name', 'phone', 'price', 'rating', 'review_count', 'transactions', 'url'])
# dict_keys(['alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id', 'image_url', 'is_closed', 'location', 'name', 'phone', 'price', 'rating', 'review_count', 'transactions', 'url'])
# ...

# %%
for d in slovnik["businesses"]:
  print(d["name"],d["rating"])
# Out:
# Lokál Dlouhááá 4.0
# Kro Kitchen bistro & rotisserie 5.0
# Czechouse Grill & Rotisserie 4.5
# Restaurace Mincovna 4.5
# U Parlamentu 4.5
# Srdcovka Spálená 3.5
# Mlejnice 4.0
# Pivovar Marina 4.0
# Pivovar U Tří růží 4.5
# U Houdků 4.5
# Hostinec U přístavu 3.0
# Lokál U Bílé kuželky 4.0
# Café Imperial 4.5
# The Blue Duckling 2 4.5
# Klášterní pivovar Strahov 4.0
# Planeta Žižkov 3.0
# Lavička 4.5
# Pivovarský dům 3.5
# Baráčnická rychta 4.5
# Karlův sklep 4.0
# U Sádlů 4.0
# Pivnice U Zlatého slona 4.5
# U Kroka 4.5
# U Dvou Sester 4.0
# Plzeňská restaurace 4.0
# Krystal bistro 4.0
# Švejk restaurant U Brázdů 4.0
# Zapomenutý čas 4.0
# Potrefená Husa Hybernská 4.0
# Restaurace Rainer Maria Rilke 4.5
# Apetit Praha 4.0
# Havlíčkova restaurace 3.5
# Bredovský dvůr 4.5
# U Provaznice 4.0
# Restaurace Tiskárna 4.5
# Restaurace pod Vyšehradem 4.0
# Havelská Koruna 4.0
# Kolkovna Celnice 3.5
# Restaurace U Veverky 4.0
# Restaurant Zvonice 5.0
# Restaurant U Špirků 3.5
# ...
